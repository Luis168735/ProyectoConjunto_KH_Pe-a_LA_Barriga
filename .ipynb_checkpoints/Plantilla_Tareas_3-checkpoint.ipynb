# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Luis Antonio Barriga Adame, .
#
# **Fecha:** 20 de febrero del 2023.
#
# **Expediente** : 730512, .
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: Link con el enlace del repositorio del creador del proyecto
#
# # Tarea 3: Clase 6

# %% [markdown]
# ## Enunciado de tarea
# >1. Resolver la siguiente ecuación recursiva usando funciones como se vió en clase
# $$ D_{n}=(n-1) D_{n-1}+(n-1) D_{n-2} \quad n\ge 3$$
# con $D_1=0$ y $D_2 = 1$
# >3. Count the number of spaces in the following string `variable =  relaciónn  requiere,  para obtener  el  valor  de un  cierto  término,  el conocimiento de los dos anteriores`.
# >4. Remove all of the vowels in a string [make a list of the non-vowels].
# >5. Find all of the words in a string that are less than 4 letters.
# >6. Use a dictionary comprehension to count the length of each word in a sentence.
# >7. Use a nested list comprehension to find all of the numbers from 1-1000 that are divisible by any single digit besides 1 (2-9).

# %% [markdown]
# ### Ejercicio 1: (enunciado) Transcribirlo

# %% [markdown]
# Código de solución estudiante 1 (Luis Barriga)

# %%
# Ejercicio 1:
def D(n):
    if n == 1:
        return 0
    elif n == 2:
        return 1
    else:
        return (n-1) * D(n-1) + (n-1) * D(n-2)
respuesta= D(1), D(2), D(5), D(8)
respuesta

#print([D(n) for n in range(1, 20)])
# Out:
# (0, 1, 44, 14833)

# %%
#Ejercicio 2:
variable = "  relaciónn  requiere,  para obtener  el  valor  de un  cierto  término,  el conocimiento de los dos anteriores"
espacios = len([x for x in variable if x == ' '])
espacios
# Out:
# 25

# %%
#Ejercicio 3:
vocales = ["a","e","i","o","u"]
Sin_vocales = list(filter(lambda x: x not in vocales, variable))
#Sin_vocales
result = ''.join(Sin_vocales)
result
# Out:
# '  rlcónn  rqr,  pr btnr  l  vlr  d n  crt  térmn,  l cncmnt d ls ds ntrrs'

# %%
#Ejercicio 4:
palabras4 = [x for x in variable.split() if len(x) < 4] # Aqui uso slpit para poder dividir mi oracion en palabras.
palabras4
# Out:
# ['el', 'de', 'un', 'el', 'de', 'los', 'dos']

# %%
#Ejercicio 5
contar = {x: len(x) for x in variable.split()}
contar
# Out:
# {'relaciónn': 9,
#  'requiere,': 9,
#  'para': 4,
#  'obtener': 7,
#  'el': 2,
#  'valor': 5,
#  'de': 2,
#  'un': 2,
#  'cierto': 6,
#  'término,': 8,
#  'conocimiento': 12,
#  'los': 3,
#  'dos': 3,
#  'anteriores': 10}

# %%
#Ejercicio 6:
numeros_div = [x for x in range(1, 1001) if any(x % digit == 0 for digit in range(2, 10))]
numeros_div
# Out:
# [2,
#  3,
#  4,
#  5,
#  6,
#  7,
#  8,
#  9,
#  10,
#  12,
#  14,
#  15,
#  16,
#  18,
#  20,
#  21,
#  22,
#  24,
#  25,
#  26,
#  27,
#  28,
#  30,
#  32,
#  33,
#  34,
#  35,
#  36,
#  38,
#  39,
#  40,
#  42,
#  44,
#  45,
#  46,
#  48,
#  49,
#  50,
#  51,
#  52,
#  54,
#  55,
#  56,
#  57,
#  58,
#  60,
#  62,
#  63,
#  64,
#  65,
#  66,
#  68,
#  69,
#  70,
#  72,
#  74,
#  75,
#  76,
#  77,
#  78,
#  80,
#  81,
#  82,
#  84,
#  85,
#  86,
#  87,
#  88,
#  90,
#  91,
#  92,
#  93,
#  94,
#  95,
#  96,
#  98,
#  99,
#  100,
#  102,
#  104,
#  105,
#  106,
#  108,
#  110,
#  111,
#  112,
#  114,
#  115,
#  116,
#  117,
#  118,
#  119,
#  120,
#  122,
#  123,
#  124,
#  125,
#  126,
#  128,
#  129,
#  130,
#  132,
#  133,
#  134,
#  135,
#  136,
#  138,
#  140,
#  141,
#  142,
#  144,
#  145,
#  146,
#  147,
#  148,
#  150,
#  152,
#  153,
#  154,
#  155,
#  156,
#  158,
#  159,
#  160,
#  161,
#  162,
#  164,
#  165,
#  166,
#  168,
#  170,
#  171,
#  172,
#  174,
#  175,
# ...

# %% [markdown]
# ### Código de solución estudiante 2

# %%
### 1 Resolver la siguiente ecuacion recursiva usando funciones 
## D1=0 y D2=1
def D(n):
    if n == 1:
        return 0
    elif n == 2:
        return 1
    else:
        return (n-1)*D(n-1)+(n-1)*D(n-2)

# %%
# D1 y D2
D(1),D(2)
# Out:
# (0, 1)

# %%
# n mayor o igual a 3
print([D(n) for n in range(3,10)])
# Out:
# [2, 9, 44, 265, 1854, 14833, 133496]

# %%
### 2 Count the number spaces in the following string
variable = 'relación requiere, para obtener el valor de un cierto termino, el conocimiento de los dos anteriores'
count_spaces= len([v for v in variable if v == ' '])
count_spaces
# Out:
# 15

# %%
### 3 Remove all the vowels of a string
vowels = "aeiouAEIOU"
remove_vowels = list(filter(lambda x: x not in vowels, variable))
non_vowels = ''.join(remove_vowels)
non_vowels
# Out:
# 'rlcón rqr, pr btnr l vlr d n crt trmn, l cncmnt d ls ds ntrrs'

# %%
### 4 Find all of the words in a string that are less than 4 letters 
def find_short_words(x):
    words = x.split()
    short_words = []
    for word in words:
        if len(word) < 4:
            short_words.append(word)
    return short_words

find_short_words(variable)
# Out:
# ['el', 'de', 'un', 'el', 'de', 'los', 'dos']

# %%
### 5 Count the length of each word in a sentence using a dictionary comprehension
count_word_lengths = {x: len(x) for x in variable.split()}
count_word_lengths
# Out:
# {'relación': 8,
#  'requiere,': 9,
#  'para': 4,
#  'obtener': 7,
#  'el': 2,
#  'valor': 5,
#  'de': 2,
#  'un': 2,
#  'cierto': 6,
#  'termino,': 8,
#  'conocimiento': 12,
#  'los': 3,
#  'dos': 3,
#  'anteriores': 10}

# %%
# 6 Use a nested list comprehension to find all of the numbers from 1-1000 that are divisible by any single digit besides 1 (2-9)
divisible_nums = [num for num in range(1, 1001) if any(num % divisor == 0 for divisor in range(2, 10))]
divisible_nums
# Out:
# [2,
#  3,
#  4,
#  5,
#  6,
#  7,
#  8,
#  9,
#  10,
#  12,
#  14,
#  15,
#  16,
#  18,
#  20,
#  21,
#  22,
#  24,
#  25,
#  26,
#  27,
#  28,
#  30,
#  32,
#  33,
#  34,
#  35,
#  36,
#  38,
#  39,
#  40,
#  42,
#  44,
#  45,
#  46,
#  48,
#  49,
#  50,
#  51,
#  52,
#  54,
#  55,
#  56,
#  57,
#  58,
#  60,
#  62,
#  63,
#  64,
#  65,
#  66,
#  68,
#  69,
#  70,
#  72,
#  74,
#  75,
#  76,
#  77,
#  78,
#  80,
#  81,
#  82,
#  84,
#  85,
#  86,
#  87,
#  88,
#  90,
#  91,
#  92,
#  93,
#  94,
#  95,
#  96,
#  98,
#  99,
#  100,
#  102,
#  104,
#  105,
#  106,
#  108,
#  110,
#  111,
#  112,
#  114,
#  115,
#  116,
#  117,
#  118,
#  119,
#  120,
#  122,
#  123,
#  124,
#  125,
#  126,
#  128,
#  129,
#  130,
#  132,
#  133,
#  134,
#  135,
#  136,
#  138,
#  140,
#  141,
#  142,
#  144,
#  145,
#  146,
#  147,
#  148,
#  150,
#  152,
#  153,
#  154,
#  155,
#  156,
#  158,
#  159,
#  160,
#  161,
#  162,
#  164,
#  165,
#  166,
#  168,
#  170,
#  171,
#  172,
#  174,
#  175,
# ...

# %% [markdown]
# 7. Como ejemplo simple de una simulación de Monte Carlo, considere calcular la probabilidad de una suma particular del lanzamiento de tres dados (cada dado tiene valores del uno al seis). Además cada dado tiene las siguientes carácterísticas: el primer dado no está cargado (distribución uniforme todos son equiprobables); el segundo y tercer dado están cargados basados en una distribución binomial con parámetros (`n=5, p=0.5` y `n=5, p=0.2`). Calcule la probabilidad de que la suma resultante sea 7, 14 o 18.

# %%
binom.pmf?

# %%
import numpy as np
from scipy.stats import binom

def sum_probability(sum_value):
    p_uniform = 1/6  # probability of getting a specific value on the uniform dice
    p_binom_1 = binom.pmf(sum_value, 5, 0.5)  # probability of getting the sum value on the binomial dice
    p_binom_2 = binom.pmf(sum_value, 5, 0.2)
    
    # calculate the probability of getting the specified sum value by summing over all possible outcomes
    prob = 0
    for i in range(1, 7):
        for j in range(1, 7):
            for k in range(1, 7):
                if i+j+k == sum_value:
                    prob += p_uniform + p_binom_1 + p_binom_2

    return prob

# %%
print([sum_probability(sum_value) for sum_value in range(6,19)])
# Out:
# [1.6666666666666667, 2.4999999999999996, 3.4999999999999987, 4.166666666666665, 4.499999999999999, 4.499999999999999, 4.166666666666665, 3.4999999999999987, 2.4999999999999996, 1.6666666666666667, 0.9999999999999999, 0.5, 0.16666666666666666]
